# %%
import pandas as pd

# %%
# total enrollment
te = pd.read_csv("data/totalenrollment.csv", index_col='UnitID')

# %%
te.head()
# Out:
#                                     Institution    2004    2005    2006  \
# UnitID
# 493868         A Better U Beauty Barber Academy     NaN     NaN     NaN
# 177834  A T Still University of Health Sciences  1855.0  2130.0  2459.0
# 180203                   Aaniiih Nakoda College   257.0   175.0   161.0
# 491464                         ABC Adult School     NaN     NaN     NaN
# 459523                       ABC Beauty Academy     NaN     NaN     NaN
#
#           2007    2008    2009    2010    2011    2012    2013    2014  \
# UnitID
# 493868     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 177834  2880.0  3480.0  3702.0  3632.0  3293.0  3141.0  3314.0  3226.0
# 180203   244.0   168.0   236.0   214.0   169.0   221.0   139.0   291.0
# 491464     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 459523     NaN     NaN     NaN    23.0    34.0    48.0    35.0    30.0
#
#           2015    2016    2017    2018    2019    2020
# UnitID
# ...

# %%
# reverse order of columns up to the first column
te_reversed = te.iloc[:,:1:-1]
te_reversed.insert(0,'Institution',te['Institution'])
te = te_reversed
